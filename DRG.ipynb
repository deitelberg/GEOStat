# %%
import geopandas as gpd
import numpy as np
import os
import pandas as pd
import pyreadstat as prs
import re

from IPython.display import display, HTML
from pathlib import Path

import config as c

# %%
print(c.drg)
for f in sorted(os.listdir(c.drg)):
    print(f)
# Out:
# ../DRG
# DRG316July.sps
# DRG_Wave3_16July.csv
# USAID DRG Wave 3_16July.sav

# %%
drgSav = os.path.join(c.drg, 'USAID DRG Wave 3_16July.sav')
df, meta = prs.read_sav(drgSav)

print('{}'.format('-'*40))
#print(df.info())
#print('{}'.format('-'*40))
print('Rows: {}  Cols: {}'.format(df.shape[0], df.shape[1]))
#pd.set_option('display.expand_frame_repr', False)
#print(df.head())
#print(display(HTML(df.head(5).to_html())))
dfAdmins = df[['region', 'munic']]
print(display(HTML(dfAdmins.head(10).to_html())))

col_names = meta.column_names
col_labels = meta.column_labels
col_names_labels = dict(zip(col_names, col_labels))
print('Names: {}  Labels: {}'.format(len(col_names), len(col_labels)))
i = 1
# for name, label in col_names_labels.items():
#     unique_cnt = len(df[name].unique())
#     print('{:<3} {:<5} {:<10}  {}'.format(i, unique_cnt, name, label))
#     i+=1

print('{}'.format('-'*40))
# i = 1
# vvl_dict = meta.variable_value_labels
# for k1, v1 in vvl_dict.items():
#     if not k1.lower() in ['region', 'munic']:
#         continue
#     print('\n({}) Code: {}\nQuestion: {}\nvalue type: {})'.format(i, k1, col_names_labels[k1], type(v1)))
#     for k2, v2 in v1.items():
#         print('    {}  {}'.format(k2, v2))
#     i+=1
# Out:
# ----------------------------------------
# Rows: 2270  Cols: 250
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>region</th>
#       <th>munic</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>1.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>1.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>1.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>1.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>1.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>1.0</td>
#       <td>1.0</td>
#     </tr>
#   </tbody>
# </table>
# None
# Names: 250  Labels: 250
# ----------------------------------------

# %%
print(meta.variable_value_labels['region'])
rDict = meta.variable_value_labels['region']
pd.DataFrame.from_dict({'Region': rDict})
dfRegion = pd.DataFrame(list(rDict.items()), index=list(rDict.keys()), columns=['RCode', 'RName'])
print(display(HTML(dfRegion.head(10).to_html())))

print(meta.variable_value_labels['munic'])
rDict = meta.variable_value_labels['munic']
pd.DataFrame.from_dict({'Munic': rDict})
dfMunic = pd.DataFrame(list(rDict.items()), index=list(rDict.keys()), columns=['MCode', 'MName'])
print(display(HTML(dfMunic.head(80).to_html())))
# Out:
# {1.0: 'Tbilisi', 2.0: 'Kakheti', 3.0: 'Kvemo Kartili', 4.0: 'Shida Kartli', 5.0: 'Samckhe-Djavakheti', 6.0: 'Adjara', 7.0: 'Guria', 8.0: 'Samegrelo-Zemo svaneti', 9.0: 'Imereti-kvemo svaneti', 10.0: 'Mckheta-Mtianeti'}
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>RCode</th>
#       <th>RName</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1.0</th>
#       <td>1.0</td>
#       <td>Tbilisi</td>
#     </tr>
#     <tr>
#       <th>2.0</th>
#       <td>2.0</td>
#       <td>Kakheti</td>
#     </tr>
#     <tr>
#       <th>3.0</th>
#       <td>3.0</td>
#       <td>Kvemo Kartili</td>
#     </tr>
#     <tr>
#       <th>4.0</th>
#       <td>4.0</td>
#       <td>Shida Kartli</td>
#     </tr>
#     <tr>
#       <th>5.0</th>
#       <td>5.0</td>
#       <td>Samckhe-Djavakheti</td>
#     </tr>
#     <tr>
#       <th>6.0</th>
#       <td>6.0</td>
#       <td>Adjara</td>
#     </tr>
#     <tr>
#       <th>7.0</th>
#       <td>7.0</td>
#       <td>Guria</td>
#     </tr>
#     <tr>
#       <th>8.0</th>
#       <td>8.0</td>
#       <td>Samegrelo-Zemo svaneti</td>
#     </tr>
#     <tr>
#       <th>9.0</th>
#       <td>9.0</td>
#       <td>Imereti-kvemo svaneti</td>
#     </tr>
#     <tr>
#       <th>10.0</th>
#       <td>10.0</td>
#       <td>Mckheta-Mtianeti</td>
#     </tr>
#   </tbody>
# </table>
# None
# {1.0: 'Mtatsminda', 2.0: 'Vake', 3.0: 'Saburtalo', 4.0: 'Krtsanisi', 5.0: 'Isani', 6.0: 'Samgori', 7.0: 'Chugureti', 8.0: 'Didube', 9.0: 'Nadzaladevi', 10.0: 'Gldani', 11.0: 'Sagarejo', 12.0: 'Gurjaani', 13.0: 'Sighnaghi', 14.0: 'Dedoplistskaro', 15.0: 'Sighnaghi', 16.0: 'Kvareli', 17.0: 'Lagodekhi', 18.0: 'Kvareli', 19.0: 'Telavi', 20.0: 'Kvareli', 21.0: 'Telavi', 22.0: 'Akhmeta', 23.0: 'Rustavi', 24.0: 'Gardabani', 25.0: 'Tetritskaro', 26.0: 'Bolnisi', 27.0: 'Dmanisi', 28.0: 'Tsalka', 29.0: 'Dmanisi', 30.0: 'Marneuli', 31.0: 'Mtskheta', 32.0: 'Dusheti', 33.0: 'Tianeti', 34.0: 'Dusheti', 35.0: 'Kaspi', 36.0: 'Kareli', 37.0: 'Gori', 38.0: 'Khashuri', 39.0: 'Adigeni', 40.0: 'Akhaltsikhe', 41.0: 'Aspindza', 42.0: 'Borjomi', 43.0: 'Akhalkalaki', 44.0: 'Ninotsminda', 45.0: 'Akhalkalaki', 46.0: 'Kutaisi', 47.0: 'Tkibuli', 48.0: 'Terjola', 49.0: 'Kharagauli', 50.0: 'Baghdati', 51.0: 'Kharagauli', 52.0: 'Zestaphoni', 53.0: 'Sachkhere', 54.0: 'Khoni', 55.0: 'Vani', 56.0: 'Samtredia', 57.0: 'Chiatura', 58.0: 'Tskaltubo', 59.0: 'Mestia', 60.0: 'Oni', 61.0: 'Ambrolauri', 62.0: 'Ozurgeti', 63.0: 'Chokhatauri', 64.0: 'Lanchkhuti', 65.0: 'Poti', 66.0: 'Martvili', 67.0: 'Abasha', 68.0: 'Martvili', 69.0: 'Senaki', 70.0: 'Khobi', 71.0: 'Zugdidi', 72.0: 'Chkhorotsku', 73.0: 'Tsalenjikha', 74.0: 'Batumi', 75.0: 'Kobuleti', 76.0: 'Khelvachauri', 77.0: 'Khulo', 78.0: 'Shuakhevi', 79.0: 'Khulo'}
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>MCode</th>
#       <th>MName</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1.0</th>
#       <td>1.0</td>
#       <td>Mtatsminda</td>
#     </tr>
#     <tr>
#       <th>2.0</th>
#       <td>2.0</td>
#       <td>Vake</td>
#     </tr>
#     <tr>
#       <th>3.0</th>
#       <td>3.0</td>
#       <td>Saburtalo</td>
#     </tr>
#     <tr>
#       <th>4.0</th>
#       <td>4.0</td>
#       <td>Krtsanisi</td>
#     </tr>
#     <tr>
#       <th>5.0</th>
#       <td>5.0</td>
#       <td>Isani</td>
#     </tr>
#     <tr>
#       <th>6.0</th>
#       <td>6.0</td>
#       <td>Samgori</td>
#     </tr>
#     <tr>
#       <th>7.0</th>
#       <td>7.0</td>
#       <td>Chugureti</td>
#     </tr>
#     <tr>
#       <th>8.0</th>
#       <td>8.0</td>
#       <td>Didube</td>
#     </tr>
#     <tr>
#       <th>9.0</th>
#       <td>9.0</td>
#       <td>Nadzaladevi</td>
#     </tr>
#     <tr>
#       <th>10.0</th>
#       <td>10.0</td>
#       <td>Gldani</td>
#     </tr>
#     <tr>
#       <th>11.0</th>
#       <td>11.0</td>
#       <td>Sagarejo</td>
#     </tr>
#     <tr>
#       <th>12.0</th>
#       <td>12.0</td>
#       <td>Gurjaani</td>
#     </tr>
#     <tr>
#       <th>13.0</th>
#       <td>13.0</td>
#       <td>Sighnaghi</td>
#     </tr>
#     <tr>
#       <th>14.0</th>
#       <td>14.0</td>
#       <td>Dedoplistskaro</td>
#     </tr>
#     <tr>
#       <th>15.0</th>
#       <td>15.0</td>
#       <td>Sighnaghi</td>
#     </tr>
#     <tr>
#       <th>16.0</th>
#       <td>16.0</td>
#       <td>Kvareli</td>
#     </tr>
#     <tr>
#       <th>17.0</th>
#       <td>17.0</td>
#       <td>Lagodekhi</td>
#     </tr>
#     <tr>
#       <th>18.0</th>
#       <td>18.0</td>
#       <td>Kvareli</td>
#     </tr>
#     <tr>
#       <th>19.0</th>
#       <td>19.0</td>
#       <td>Telavi</td>
#     </tr>
#     <tr>
#       <th>20.0</th>
#       <td>20.0</td>
#       <td>Kvareli</td>
#     </tr>
#     <tr>
#       <th>21.0</th>
#       <td>21.0</td>
#       <td>Telavi</td>
#     </tr>
#     <tr>
#       <th>22.0</th>
#       <td>22.0</td>
#       <td>Akhmeta</td>
#     </tr>
#     <tr>
#       <th>23.0</th>
#       <td>23.0</td>
#       <td>Rustavi</td>
#     </tr>
#     <tr>
#       <th>24.0</th>
#       <td>24.0</td>
#       <td>Gardabani</td>
#     </tr>
#     <tr>
#       <th>25.0</th>
#       <td>25.0</td>
#       <td>Tetritskaro</td>
#     </tr>
#     <tr>
#       <th>26.0</th>
#       <td>26.0</td>
#       <td>Bolnisi</td>
#     </tr>
#     <tr>
#       <th>27.0</th>
#       <td>27.0</td>
#       <td>Dmanisi</td>
#     </tr>
#     <tr>
#       <th>28.0</th>
#       <td>28.0</td>
#       <td>Tsalka</td>
#     </tr>
#     <tr>
#       <th>29.0</th>
#       <td>29.0</td>
#       <td>Dmanisi</td>
#     </tr>
#     <tr>
#       <th>30.0</th>
#       <td>30.0</td>
#       <td>Marneuli</td>
#     </tr>
#     <tr>
#       <th>31.0</th>
#       <td>31.0</td>
#       <td>Mtskheta</td>
#     </tr>
#     <tr>
#       <th>32.0</th>
#       <td>32.0</td>
#       <td>Dusheti</td>
#     </tr>
#     <tr>
#       <th>33.0</th>
#       <td>33.0</td>
#       <td>Tianeti</td>
#     </tr>
#     <tr>
#       <th>34.0</th>
#       <td>34.0</td>
#       <td>Dusheti</td>
#     </tr>
#     <tr>
#       <th>35.0</th>
#       <td>35.0</td>
#       <td>Kaspi</td>
#     </tr>
#     <tr>
#       <th>36.0</th>
#       <td>36.0</td>
#       <td>Kareli</td>
#     </tr>
#     <tr>
#       <th>37.0</th>
#       <td>37.0</td>
#       <td>Gori</td>
#     </tr>
#     <tr>
#       <th>38.0</th>
#       <td>38.0</td>
#       <td>Khashuri</td>
#     </tr>
#     <tr>
#       <th>39.0</th>
#       <td>39.0</td>
#       <td>Adigeni</td>
#     </tr>
#     <tr>
#       <th>40.0</th>
#       <td>40.0</td>
#       <td>Akhaltsikhe</td>
#     </tr>
#     <tr>
#       <th>41.0</th>
#       <td>41.0</td>
#       <td>Aspindza</td>
#     </tr>
#     <tr>
#       <th>42.0</th>
#       <td>42.0</td>
#       <td>Borjomi</td>
#     </tr>
#     <tr>
#       <th>43.0</th>
#       <td>43.0</td>
#       <td>Akhalkalaki</td>
#     </tr>
#     <tr>
#       <th>44.0</th>
#       <td>44.0</td>
#       <td>Ninotsminda</td>
#     </tr>
#     <tr>
#       <th>45.0</th>
#       <td>45.0</td>
#       <td>Akhalkalaki</td>
#     </tr>
#     <tr>
#       <th>46.0</th>
#       <td>46.0</td>
#       <td>Kutaisi</td>
#     </tr>
#     <tr>
#       <th>47.0</th>
#       <td>47.0</td>
#       <td>Tkibuli</td>
#     </tr>
#     <tr>
#       <th>48.0</th>
#       <td>48.0</td>
#       <td>Terjola</td>
#     </tr>
#     <tr>
#       <th>49.0</th>
#       <td>49.0</td>
#       <td>Kharagauli</td>
#     </tr>
#     <tr>
#       <th>50.0</th>
#       <td>50.0</td>
#       <td>Baghdati</td>
#     </tr>
#     <tr>
#       <th>51.0</th>
#       <td>51.0</td>
#       <td>Kharagauli</td>
#     </tr>
#     <tr>
#       <th>52.0</th>
#       <td>52.0</td>
#       <td>Zestaphoni</td>
#     </tr>
#     <tr>
#       <th>53.0</th>
#       <td>53.0</td>
#       <td>Sachkhere</td>
#     </tr>
#     <tr>
#       <th>54.0</th>
#       <td>54.0</td>
#       <td>Khoni</td>
#     </tr>
#     <tr>
#       <th>55.0</th>
#       <td>55.0</td>
#       <td>Vani</td>
#     </tr>
#     <tr>
#       <th>56.0</th>
#       <td>56.0</td>
#       <td>Samtredia</td>
#     </tr>
#     <tr>
#       <th>57.0</th>
#       <td>57.0</td>
#       <td>Chiatura</td>
#     </tr>
#     <tr>
#       <th>58.0</th>
#       <td>58.0</td>
#       <td>Tskaltubo</td>
#     </tr>
#     <tr>
#       <th>59.0</th>
#       <td>59.0</td>
#       <td>Mestia</td>
#     </tr>
#     <tr>
#       <th>60.0</th>
#       <td>60.0</td>
#       <td>Oni</td>
#     </tr>
#     <tr>
#       <th>61.0</th>
#       <td>61.0</td>
#       <td>Ambrolauri</td>
#     </tr>
#     <tr>
#       <th>62.0</th>
#       <td>62.0</td>
#       <td>Ozurgeti</td>
#     </tr>
#     <tr>
#       <th>63.0</th>
#       <td>63.0</td>
#       <td>Chokhatauri</td>
#     </tr>
#     <tr>
#       <th>64.0</th>
#       <td>64.0</td>
#       <td>Lanchkhuti</td>
#     </tr>
#     <tr>
#       <th>65.0</th>
#       <td>65.0</td>
#       <td>Poti</td>
#     </tr>
#     <tr>
#       <th>66.0</th>
#       <td>66.0</td>
#       <td>Martvili</td>
#     </tr>
#     <tr>
#       <th>67.0</th>
#       <td>67.0</td>
#       <td>Abasha</td>
#     </tr>
#     <tr>
#       <th>68.0</th>
#       <td>68.0</td>
#       <td>Martvili</td>
#     </tr>
#     <tr>
#       <th>69.0</th>
#       <td>69.0</td>
#       <td>Senaki</td>
#     </tr>
#     <tr>
#       <th>70.0</th>
#       <td>70.0</td>
#       <td>Khobi</td>
#     </tr>
#     <tr>
#       <th>71.0</th>
#       <td>71.0</td>
#       <td>Zugdidi</td>
#     </tr>
#     <tr>
#       <th>72.0</th>
#       <td>72.0</td>
#       <td>Chkhorotsku</td>
#     </tr>
#     <tr>
#       <th>73.0</th>
#       <td>73.0</td>
#       <td>Tsalenjikha</td>
#     </tr>
#     <tr>
#       <th>74.0</th>
#       <td>74.0</td>
#       <td>Batumi</td>
#     </tr>
#     <tr>
#       <th>75.0</th>
#       <td>75.0</td>
#       <td>Kobuleti</td>
#     </tr>
#     <tr>
#       <th>76.0</th>
#       <td>76.0</td>
#       <td>Khelvachauri</td>
#     </tr>
#     <tr>
#       <th>77.0</th>
#       <td>77.0</td>
#       <td>Khulo</td>
#     </tr>
#     <tr>
#       <th>78.0</th>
#       <td>78.0</td>
#       <td>Shuakhevi</td>
#     </tr>
#     <tr>
#       <th>79.0</th>
#       <td>79.0</td>
#       <td>Khulo</td>
#     </tr>
#   </tbody>
# </table>
# None
